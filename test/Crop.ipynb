# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
pip install tifffile as tifi
# Out:
# Requirement already satisfied: tifffile in /usr/local/lib/python3.7/dist-packages (2021.11.2)
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %%
import os
import glob
workspace_path = '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test' 
data_path = os.path.join(workspace_path, 'dataset/source')
data_paths= glob.glob(os.path.join(workspace_path, 'dataset/source/*.tif'))
save_path = os.path.join(workspace_path, 'dataset/Image_crop/')

# %%
data_paths
# Out:
# ['/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_4116.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_5901.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_0552.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_5155.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_3934.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_2415.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_3904.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_5303.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_0556.tif',
#  '/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_1624.tif']

# %%
# OpenCV 패키지 사용

os.environ["OPENCV_IO_MAX_IMAGE_PIXELS"] = pow(2,33).__str__()
import cv2 # import after setting OPENCV_IO_MAX_IMAGE_PIXELS
# from google.colab.patches import cv2_imshow  # colab 용 cv2.imshow
import matplotlib.pyplot as plt  # 시각화 도구
import numpy as np

# %%
img_WHOLE=cv2.imread(os.path.join(data_path,'0820_4116.tif'), cv2.IMREAD_COLOR)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-69-861139deeb55> in <module>()
# ----> 1 img_WHOLE=cv2.imread(os.path.join(data_path,'0820_4116.tif'), cv2.IMREAD_COLOR)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgcodecs/src/loadsave.cpp:75: error: (-215:Assertion failed) pixels <= CV_IO_MAX_IMAGE_PIXELS in function 'validateInputImageSize'

# %%
img_WHOLE.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-1afae096fe65> in <module>()
# ----> 1 img_WHOLE.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.imshow(img_WHOLE)

# %%
img_WHOLE_rgb=img_WHOLE[...,[2,1,0]]
#img_WHOLE_rgb=cv2.cvtColor(img_WHOLE,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_WHOLE_rgb)

# %%
img_WHOLE.shape[0]
# Out:
# 19456

# %%
# Train Set Crop
img_crop = []
i = 0
for i in

for height in range(0, img_WHOLE.shape[0], 512):
    for width in range(0, 8704, 512):
        i += 1
        img_rgb_crop = img_WHOLE_rgb[height:height+512, width:width+512, :]  # 30*30 절삭(높이, 너비)
        img_crop.append(img_rgb_crop)
        cv2.imwrite(save_path + '/%05d.jpg' % i, img_rgb_crop)
        # cv2.imwrite('./data/train_512/' + str('y_' + str(height)+'_x_'+str(width)) + '.jpg', img_rgb_crop)

# %%
len(img_crop)
# Out:
# 272

# %%
img_crop[0].shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(img_crop[268])

# %%
for i in data_paths:
    img_crop=[]
    num=0
    i[-8:-4]
    img_rgb=tifi.imread(i, cv2.IMREAD_COLOR)
    #img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    for height in range(0, img_rgb.shape[0], 512):
        for width in range(0, img_rgb.shape[1], 512):
            num += 1
            img_rgb_crop = img_rgb[height:height+512, width:width+512, :]  # 30*30 절삭(높이, 너비)
            img_crop.append(img_rgb_crop)
            cv2.imwrite(os.path.join(save_path,i[-8:-4]+'_crop')+'/%05d.jpg' % num, img_rgb_crop)
    break
            # cv2.imwrite('./data/train_512/' + str('y_' + str(height)+'_x_'+str(width)) + '.jpg', img_rgb_crop)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-db3547e1827b> in <module>()
#       5     img_rgb=tifi.imread(i, cv2.IMREAD_COLOR)
#       6     #img_rgb=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# ----> 7     for height in range(0, img_rgb.shape[0], 512):
#       8         for width in range(0, img_rgb.shape[1], 512):
#       9             num += 1
#
# AttributeError: 'ZarrTiffStore' object has no attribute 'shape'

# %%
for i in data_paths:
    print(i)
# Out:
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_4116.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_5901.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_0552.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_5155.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_3934.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_2415.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_3904.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_5303.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_0556.tif
# /gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/1102_1624.tif

# %%
os.path.join('a','b','c')
# Out:
# 'a/b/c'

# %%
import tifffile as tifi
testimg=tifi.imread('/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_4116.tif', cv2.IMREAD_COLOR)
plt.imshow(testimg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-233b1811b7f6> in <module>()
#       1 import tifffile as tifi
#       2 testimg=tifi.imread('/gdrive/MyDrive/College/캡스톤디자인 (Development of histologic and pathological photographic intellectualization analysis system)/test/dataset/source/0820_4116.tif', cv2.IMREAD_COLOR)
# ----> 3 plt.imshow(testimg)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5624                               resample=resample, **kwargs)
#    5625
# -> 5626         im.set_data(X)
#    5627         im.set_alpha(alpha)
#    5628         if im.get_clip_path() is None:
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py in set_data(self, A)
#     692                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     693             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 694                             "float".format(self._A.dtype))
#     695
#     696         if not (self._A.ndim == 2
#
# TypeError: Image data of dtype <U7 cannot be converted to float
